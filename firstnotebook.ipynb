# %%
import pandas as pd
data = pd.read_csv('womeninstem.csv')
rank = data['rank']
rank
# Out:
# 1    2419
# 2    2416
# 3    2415
# 4    2417
# Name: rank, dtype: int64

# %%
print(data.head()) #will print the first 5 items in the csv file

# %%
data.iloc[0] #prints the row at index 0

# %%
data.iloc[0:5] #prints a chart of the first 5 items in the csv file

# %%
data.plot(x="major_code", y="rank", kind="line")

# %%
women_stem = pd.read_csv("womeninstem.csv", index_col=2, parse_dates=True)
women_stem.plot() #draws a nice line graph

# %%
import matplotlib.pyplot as plt 

labels = [2419, 2416, 2415, 2417, 0]
women = ['0', '1', '2', '3', '4']
width = .5
fig, ax = plt.subplots()
ax.bar(labels, women, width)
ax.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3111150e00a9> in <module>()
#       6 fig, ax = plt.subplots()
#       7 ax.bar(labels, women, width)
# ----> 8 ax.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'
